# %%
import os
from voc12 import my_dataloader
from utility.image_util import *
from utility import util

import numpy as np

# %%
img_root = "../Dataset/VOC2012/JPEGImages"
voc_root = "../Dataset/VOC2012/"
cam_root = "../result/val_cam/"

# %%
img_list = my_dataloader.load_img_id_list("voc12/val.txt")

idx = 21

name = img_list[idx]

# %%
high_res = np.load(os.path.join(cam_root, name + ".npy"), allow_pickle=True).item()['high_res']
img = read_image(os.path.join(img_root, name +".jpg"))
for i in range(len(high_res)):
    conf_cam = util.find_conf_cam(high_res[i])
    crop_box = util.find_crop_box(conf_cam)
    cropped_img = util.crop_image_with_bounding_box(img, crop_box)
    
    image_show(cropped_img)

# %%
image_show(util.visualize_total_box(img, high_res))

# %%
image_show(high_res[0])

# %%
image_show(img)
